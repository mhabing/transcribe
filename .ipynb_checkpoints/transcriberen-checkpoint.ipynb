# %%
import openai
import os
import re
import xml.etree.ElementTree as ET

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key  = os.getenv('OPENAI_API_KEY')

def get_completion(prompt, model="gpt-4"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content
client = openai.OpenAI()

def get_completion_text( prompt, text, model="gpt-4"):
    messages = [{"role": "user", "content": prompt + "```" + text + "```"}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content
client = openai.OpenAI()

# %%
def readtext( fname):
    tree = ET.parse( fname)
    root = tree.getroot()

    ns = {'page': 'http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15'}
    text = ""

    for textline in root.iterfind( './/page:TextLine/page:TextEquiv[last()]/page:Unicode', ns):
        if textline.text != None:
            text = text + textline.text + "\n"
    return( text)

# %%
def createhtml(  tekst):
    html = ET.Element( 'html')
    head = ET.SubElement( html, 'head')
    body = ET.SubElement( html, 'body')

    title = ET.SubElement( head, 'title')
    title.text = tekst
    stylesheet = ET.SubElement( head, 'link')
    stylesheet.set( 'rel', 'stylesheet')
    stylesheet.set( 'href', 'style.css')

    return html

# %%
fnames = [ 
    "NL-HaNA_1.04.02_4994_0003-groot.xml" , "NL-HaNA_1.04.02_4994_0004-groot.xml"
#    , "NL-HaNA_1.04.02_4994_0005-groot.xml",
#    "NL-HaNA_1.04.02_4994_0006-groot.xml"
#    , "NL-HaNA_1.04.02_4994_0007-groot.xml", "NL-HaNA_1.04.02_4994_0008-groot.xml"
    ]

html = createhtml( fname)
body = html.find( 'body')

text = ""
prompt = f"""
de tekst tussen backticks is uit een VOC brief van de 1629. Vertaal de tekst tussen drie backticks naar het Nederlands. Er kunnen
schrijffouten in de tekst zitten. Er worden synoniemen gebruikt, bijvoorbeeld Jerommus, Jermmus Conteeles, Gerommus en Jeronius zijn 
allemaal Jeronimus Cornelisz. Namen zijn meestal geschreven als voornaam achternaam beroep. het woord Item betekent een nieuwe aanklacht.
geef de vertaling zonder backticks of quotes.
"""

for fname in fnames:
    text = readtext( fname)
    response = get_completion_text( prompt, text)

    ET.SubElement( body, 'h1').text = fname
    ET.SubElement( body, 'p').text = response
    

ET.ElementTree( html).write( 'inv 4994.html')

# %%
prompt = f"""
de tekst tussen backticks is een transcriptie van een zeventiende eeuws document van de VOC. De tekst bevat spelfouten en synoniemen.
Bijvoorbeeld Jerommus, Jermmus, Hieronoymus en Jeronimus zijn allemaal synoniem voor Jeronimus. 
De volgende personen 
Kun je mogelijke spelfouten vinden en verbeteringen voorstellen?
```{text}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Hier zijn enkele mogelijke spelfouten en verbeteringen:
#
# 1. "haerb" moet waarschijnlijk "haar" zijn.
# 2. "apotee" kan "apotheker" zijn.
# 3. "Coopm" kan "koopman" zijn.
# 4. "eerongeluckte" kan "eerder ongelukte" zijn.
# 5. "batavi„" kan "Batavia" zijn.
# 6. "grouwe" kan "grouwen" zijn.
# 7. "buijten" kan "buiten" zijn.
# 8. "schipr" kan "schipper" zijn.
# 9. "aruren" kan "auren" zijn.
# 10. "durckendam" kan "Durgerdam" zijn.
# 11. "tselve" kan "hetzelfde" zijn.
# 12. "vermordt" kan "vermoord" zijn.
# 13. "rommus" kan "Jeronimus" zijn.
# 14. "allert" kan "Allert" zijn.
# 15. "assendelft" kan "Assendelft" zijn.
# 16. "bosschieter" kan "boschieter" zijn.
# 17. "feijt" kan "feit" zijn.
# 18. "eijndelijck" kan "eindelijk" zijn.
# 19. "eeft" kan "heeft" zijn.
# 20. "Comman" kan "Commandeur" zijn.
# 21. "pelsaert" kan "Pelsaert" zijn.
# 22. "domliggend" kan "domliggend" zijn.
# 23. "getuijgenisse" kan "getuigenis" zijn.
# 24. "ferommus" kan "Jeronimus" zijn.
# ...

# %%
prompt_namen = f"""
de tekst tussen backticks is uit een VOC verslag van de 1629. Er kunnen
schrijffouten in de tekst zitten. Er worden synoniemen gebruikt, bijvoorbeeld Jerommus, Jermmus Conteeles, Gerommus en Jeronius zijn 
allemaal Jeronimus Cornelisz. Namen zijn meestal geschreven als voornaam achternaam beroep. 
het woord Item betekent een nieuwe aanklacht. 

Maak een lijst met namen gevogld door beroep op deze manier:
<name>Jeronimus Cornelisz</name><beroep>Coopman<beroep>
<name>Fransisco Pelsaert</name><beroep>kapitein</beroep>
```{text}```
"""

response = get_completion( prompt_namen)
print( response)
# Out:
# ```Dat hij Hendrik Jansen van Purmerend, die bij Kaelmors de Syams onder de koopman wandelde, maar gebonden zijnde, hem het hoofd zoude afstoten, waartoe hij Jeronimus een dolk in de hand gaf en heeft hij het voornoemde hoofd zelf ook afgeslagen.
#
# ...

# %%
prompt_data = f"""
de tekst tussen backticks is uit een VOC verslag van de 1629. Er kunnen
schrijffouten in de tekst zitten. Er worden synoniemen gebruikt, bijvoorbeeld Jerommus, Jermmus Conteeles, Gerommus en Jeronius zijn 
allemaal Jeronimus Cornelisz. Namen zijn meestal geschreven als voornaam achternaam beroep. 
het woord Item betekent een nieuwe aanklacht. 

Maak een lijst van data op deze manier:
<date>4 juni 1629</date>
<date>5 juni 1629</date>
```{text}```
"""

response = get_completion( prompt_data)
print( response)
# Out:
# <date>16 augustus 1629</date>

# %%
ns = {'page': 'http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15'}

fname =     "NL-HaNA_1.04.02_1098_1205-groot.xml"

tree = ET.parse( fname)
root = tree.getroot()

vertaling = ET.Element( 'html')
ET.SubElement( vertaling, 'head')
body = ET.SubElement( vertaling, 'body')

for textline in root.iterfind( './/page:TextLine/page:TextEquiv[last()]/page:Unicode', ns):
    if textline.text != None:
        text = textline.text
        prompt = f"""
de tekst tussen backticks is een regel uit een VOC verslag van de 1629. Vertaal de regel tussen drie backticks naar het Nederlands. Er kunnen
schrijffouten in de tekst zitten. Er worden synoniemen gebruikt, bijvoorbeeld Jerommus, Jermmus Conteeles, Gerommus en Jeronius zijn 
allemaal Jeronimus Cornelisz. Namen zijn meestal geschreven als voornaam achternaam beroep. het woord Item betekent een nieuwe aanklacht.
antwoord alleen met de vertaling zonder quotes of aanhalingstekens.
```{text}```
"""
        response = get_completion( prompt)
        regel = ET.SubElement( body, 'p')
        regel.text = response

ET.ElementTree( vertaling).write( 'test.html')

# %%
fname = "iiif-service_gdc_gdcwdl_wd_l__03_08_2_wdl_03082_1068948-full-pct_100-0-default.xml"

text = readxml( fname)

prompt = f"""
de tekst tussen backticks is uit een zestiende eeuws verslag van de zeevaarder Magelaen. vertaal dit naar het Nederlands
```{text}```
"""

response = get_completion( prompt)
print( response)
# Out:
# ```Proloog van Anthome Digaphete over zijn huidige werk
# behandelend de navigatie van de eilanden van Maluku door Fernand de Maga
# clianes, Portugese kapitein-generaal van de reizende vloot. En de
# haat die de schippers en andere kapiteins tegen hem hadden
# Hoofdstuk. Eerste.
# Omdat er veel nieuwsgierige mensen zijn (zeer
# illustere en zeer eerbiedwaardige Heer) die niet
# alleen tevreden zijn met het horen en weten
# de grote en wonderbaarlijke dingen die God
# mij heeft toegestaan te zien en te lijden tijdens de lange en gevaarlijke navigatie
# die ik hieronder heb geschreven. Maar ze willen ook de
# middelen en manieren en de weg weten die ik heb genomen om er te komen, niet toevoegend
# geloof of vaste overtuiging aan het einde als ze eerst niet
# goed geïnformeerd en verzekerd zijn van het begin. Daarom
# Mijnheer, het zal u behagen te begrijpen dat ik me bevond in
# ...
